# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns # used for statistical data visualization
import plotly.express as px # used for interactive data visualization
import plotly.graph_objects as go # used for creating more complex and customized visualizations
import numpy as np

# %%
sns.get_dataset_names() #to get the list of available datasets in seaborn
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df1 = sns.load_dataset('iris') # to load the iris dataset from seaborn library and store it in a variable called df1
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Line Plot

sns.lineplot(x='sepal_length', y='sepal_width', data=df1) # to create a line plot using seaborn library with sepal_length on x-axis and sepal_width on y-axis
plt.show()

# %%
px.line(df2, x = 'Age', y = 'Salary', title = 'Age vs Salary') # to create a line plot using plotly express library with Age on x-axis and Salary on y-axis and set the title of the plot to 'Age vs Salary'

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=df1, hue='species') # to create a scatter plot using seaborn library with sepal_length on x-axis and sepal_width on y-axis and color the points based on the species column
plt.show()

# %%
px.scatter(df1, x='sepal_length', y='sepal_width', color='species') # to create a scatter plot using plotly express library with sepal_length on x-axis and sepal_width on y-axis and color the points based on the species column

# %%
sns.barplot(x='species', y='sepal_length', data=df1, hue='species') # to create a bar plot using seaborn library with species on x-axis and sepal_length on y-axis and color the bars based on the species column
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
px.bar(df1, x='species', y='sepal_length', color='species', barmode = 'group') # to create a bar plot using plotly express library with species on x-axis and sepal_length on y-axis and color the bars based on the species column and set the barmode to 'group' to group the bars by species

# %%
sns.histplot(x='sepal_length', data=df1, hue='species', kde=True) # to create a histogram using seaborn library with sepal_length on x-axis and color the bars based on the species column and add a kernel density estimate (kde) to the plot
plt.show()

# %%
px.histogram(df1, x='sepal_length', color='species', nbins = 20) # to create a histogram using plotly express library with sepal_length on x-axis and color the bars based on the species column and set the number of bins to 20

# %%
sns.countplot(x='species', data=df1) # to create a count plot using seaborn library with species on x-axis and count the number of occurrences of each species in the dataset
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
px.histogram(df1, x='sepal_length', color='species', barmode='group', marginal='box') # to create a histogram using plotly express library with sepal_length on x-axis and color the bars based on the species column and set the barmode to 'group' to group the bars by species and add a box plot to the margins of the histogramS

# %%
sns.boxenplot(x='species', y='sepal_length', data=df1) # to create a box plot using seaborn library with species on x-axis and sepal_length on y-axis to visualize the distribution of sepal_length for each species
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
px.box(df1, x='species', y='sepal_length', color='species') # to create a box plot using plotly express library with species on x-axis and sepal_length on y-axis and color the boxes based on the species column

# %%
corr = df1.corr(numeric_only=True) # to calculate the correlation matrix of the numeric columns in the df1 dataset and store it in a variable called corr
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
px.imshow(corr, text_auto=True) # to create a heatmap using plotly express library with the correlation matrix corr and display the correlation values as text on the heatmap
