# %%
def greet():
    print("Hello World")

# %%
greet()
# Out:
# Hello World

# %%
def greet(name):
    print (f"Hello ,{name}!")

# %%
greet("suraj")
# Out:
# Hello ,suraj!

# %%
def add (a,b):
    return a + b

# %%
add (2,3)
# Out:
# 5

# %%
def intro(name, age):
    print (f"My name {name} and I am {age} years old.")

# %%
intro("Suraj", 20)
# Out:
# My name Suraj and I am 20 years old.

# %%
def factorial(n):   
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

# %%
factorial(10)
# Out:
# 3628800

# %%
from math import factorial
factorial(10)
# Out:
# 3628800
